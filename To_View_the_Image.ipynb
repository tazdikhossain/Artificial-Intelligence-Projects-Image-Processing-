# %% [markdown]
# <a href="https://colab.research.google.com/github/tazdikhossain/Artificial-Intelligence-Projects-Image-Processing-/blob/main/To_View_the_Image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy

import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image

img = image.load_img("/content/pexels-photo-57905.webp")

# %%
plt.imshow(img)

# %%
cv2.imread("/content/pexels-photo-57905.webp")
# Out:
# array([[[35, 35, 35],
#         [37, 37, 37],
#         [41, 41, 41],
#         ...,
#         [10, 10, 10],
#         [10, 10, 10],
#         [10, 10, 10]],
#
#        [[35, 35, 35],
#         [37, 37, 37],
#         [41, 41, 41],
#         ...,
#         [10, 10, 10],
#         [10, 10, 10],
#         [10, 10, 10]],
#
#        [[35, 35, 35],
#         [37, 37, 37],
#         [41, 41, 41],
#         ...,
#         [10, 10, 10],
#         [10, 10, 10],
#         [10, 10, 10]],
#
#        ...,
#
#        [[26, 26, 26],
#         [26, 26, 26],
#         [27, 27, 27],
#         ...,
#         [20, 20, 20],
#         [20, 20, 20],
#         [20, 20, 20]],
#
#        [[26, 26, 26],
#         [26, 26, 26],
#         [27, 27, 27],
#         ...,
#         [20, 20, 20],
#         [20, 20, 20],
#         [20, 20, 20]],
#
#        [[26, 26, 26],
#         [26, 26, 26],
#         [27, 27, 27],
#         ...,
#         [21, 21, 21],
#         [21, 21, 21],
#         [21, 21, 21]]], dtype=uint8)
